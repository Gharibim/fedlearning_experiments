# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time
import binarytree

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs
from utils import averageModels, normalModels

# %%
class Arguments():
    def __init__(self):
        self.images = 60000
        self.clients = 5
        self.rounds = 10
        self.epochs = 5
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1.0
        self.drop_rate = 0.0
        self.torch_seed = 0
        self.log_interval = 100
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = False

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
writer = open('5_experiments_mnist.csv', 'a')

# %%
hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process

# %%
# # Download MNIST manually using 'wget' then uncompress the file
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid)

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
#     client['samples'] = len(trainset_ind_list) / args.images
    client['samples'] = len(trainset_ind_list) / (len(trainset_ind_list) * args.clients)

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def ClientUpdate(args, device, client):
    client['model'].train()
#     client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
#             data = data.send(client['hook'])
#             target = target.send(client['hook'])
            
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
            output = client['model'](data)
            loss = F.nll_loss(output, target)
            loss.backward()
            client['optim'].step()
            
            if batch_idx % args.log_interval == 0:
#                 loss = loss.get() 
                print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * batch_idx / len(client['trainset']), loss))
                
#     client['model'].get()

# %%
def test(args, model, device, test_loader, name):
    model.eval()   
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    writer.write('{},'.format(100. * correct / len(test_loader.dataset)))

# %%
def Aggregate(all_models, sample_client):
    all_dicts = {}
    for client in all_models:
        all_dicts[client] = all_models[client].state_dict()
    output_dict = copy.deepcopy(all_dicts[sample_client])
    for key in all_dicts[sample_client]:
        for val in all_dicts:
            if val == sample_client:
                continue
            output_dict[key] += all_dicts[val][key]
#         output_dict[key] /= float(len(all_dicts))
        output_dict[key] /= float(len(all_models))
    output_model = Net().to(device)
    output_model.load_state_dict(output_dict)
    return output_model

# %%
def BtreeAvg(root):
    global global_model
    temp_model = Aggregate({'root':root.value[1], 'global':global_model}, 'global')
    
    if (root.left == None and root.right == None): 
        return temp_model
    left = None
    right = None
    if root.left:
        left = BtreeAvg(root.left)
    if root.right:
        right = BtreeAvg(root.right)

    if left and right:
        return Aggregate({'root':root.value[1], 'left':left, 'right':right}, 'left')
    if left:
        return Aggregate({'root':root.value[1], 'left':left}, 'left')
    if right:
        return Aggregate({'root':root.value[1],'right':right}, 'right')

# %%
def BtreeAvgSecond(root, final):
    temp_model = Aggregate({'root':root.value[1], 'global':final}, 'global')
    
    if (root.left == None and root.right == None): 
        return temp_model
    left = None
    right = None
    if root.left:
        left = BtreeAvgSecond(root.left, temp_model)
    if root.right:
        right = BtreeAvgSecond(root.right, temp_model)

    if left and right:
        return Aggregate({'root':root.value[1], 'left':left, 'right':right}, 'left')
    if left:
        return Aggregate({'root':root.value[1], 'left':left}, 'left')
    if right:
        return Aggregate({'root':root.value[1],'right':right}, 'right')

# %%
torch.manual_seed(args.torch_seed)
global_model = Net()
# torch.manual_seed(args.torch_seed)
# normal_avg = Net()

for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

tree_List = []
for inds, i in enumerate(clients):
    temp = [None] * 3
    temp[0] = i
    temp[1] = clients[inds]['model']
    temp[2] = clients[inds]['hook'].id
    tree_List.append(temp)

root = None
root = binarytree.insertLevelOrder(tree_List, root, 0, len(tree_List))
# root.printTree()

start_time = time.time()

for fed_round in range(args.rounds):
    
#     uncomment if you want a randome fraction for C every round
#     args.C = float(format(np.random.random(), '.1f'))
    
    # number of selected clients
    m = int(max(args.C * args.clients, 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
    np.random.seed(fed_round)
    active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
    active_clients = [clients[i] for i in active_clients_inds]
    
    # Training 
    for client in active_clients:
        ClientUpdate(args, device, client)
        
#     global_model = averageModels(global_model, active_clients)
#     test(args, global_model, device, global_test_loader, 'Global')
#     normal_avg = normalModels(normal_avg, active_clients)
#     test(args, normal_avg, device, global_test_loader, 'Global')
    
    
    # Begin the Btree
#     final_model = BtreeAvg(root)
    final_model = BtreeAvgSecond(root, global_model)
#     glo_model = copy.deepcopy(final_model)
    global_model.load_state_dict(final_model.state_dict())
#     test(args, global_model, device, global_test_loader, 'Global')
#     break
    
#     # Testing 
#     for client in active_clients:
#         test(args, client['model'], device, client['testset'], client['hook'].id)
    
#     # Averaging 
#     global_model = averageModels(global_model, active_clients)
    
    # Testing the average model
    test(args, global_model, device, global_test_loader, 'Global')
            
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())

writer.write('\n')
end_time = time.time() 
hours, rem = divmod(end_time-start_time, 3600)
minutes, seconds = divmod(rem, 60)
writer.write('{:0>2}:{:0>2}:{:05.2f}'.format(int(hours),int(minutes),seconds))
writer.write('\n')
writer.close()

if (args.save_model):
    torch.save(global_model.state_dict(), "FedAvg.pt")
# Out:
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.312409
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.210200
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.695333
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.484380
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.326328
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.160283
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.254630
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.280988
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.297055
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.127146
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.319904
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.307307
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.568714
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.344530
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.397112
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.396674
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.196200
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.186076
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.175233
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.153745
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.320340
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.198466
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.535064
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.437902
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.442365
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.267823
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.324219
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.305271
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.281176
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.119724
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.324182
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.090364
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.398441
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.374103
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.206763
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.383896
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.340043
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.162760
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.154247
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.150936
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.310031
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.256259
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.652084
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.343384
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.430592
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.164233
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.314569
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.359523
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.315863
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.215174
#
# Test set: Average loss for Global model: 0.1882, Accuracy: 9518/10000 (95%)
#
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.310910
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.126175
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.115884
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.080712
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.127543
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.152879
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.052537
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.114323
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.068453
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.214541
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.169965
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.237873
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.177606
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.542431
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.159213
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.070341
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.170924
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.116103
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.102268
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.110835
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.123336
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.097826
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.256156
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.071461
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.172216
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.070728
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.050685
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.101500
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.196163
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.115685
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.125042
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.203017
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.108629
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.215977
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.098723
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.090252
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.178445
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.165269
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.053154
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.183822
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.174045
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.140746
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.168900
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.125227
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.079247
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.063335
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.116917
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.266355
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.046348
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.115001
#
# Test set: Average loss for Global model: 0.0928, Accuracy: 9727/10000 (97%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.098885
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.072049
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.110746
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.064311
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.084326
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.020691
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.108531
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.058143
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.058141
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.081533
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.157895
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.104590
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.042694
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.131891
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.145301
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.045642
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.057107
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.066420
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.037523
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.133223
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.091667
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.148846
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.133134
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.133414
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.052546
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.037464
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.139384
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.137512
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.059425
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.031092
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.119644
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.195909
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.115482
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.050965
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.034225
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.151477
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.080735
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.100154
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.017018
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.083005
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.095812
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.213815
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.163622
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.048940
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.026425
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.038092
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.076616
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.176610
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.035988
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.021626
#
# Test set: Average loss for Global model: 0.0732, Accuracy: 9763/10000 (98%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.013639
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.110229
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.083490
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.017745
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.179155
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.079789
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.025384
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.017967
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.089782
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.029248
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.147801
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.057914
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.025321
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.037513
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.073223
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.021154
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.047593
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.131147
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.048194
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.024094
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.024484
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.037075
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.080300
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.079342
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.209355
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.046225
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.025834
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.139743
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.053459
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.167911
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.238193
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.045546
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.047350
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.047890
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.061533
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.039336
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.024490
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.029224
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.097552
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.020813
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.152276
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.040910
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.042921
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.123774
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.051343
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.113450
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.024944
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.020184
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.043967
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.021907
#
# Test set: Average loss for Global model: 0.0575, Accuracy: 9822/10000 (98%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.009537
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.021116
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.017576
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.143337
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.021508
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.070140
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.008977
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.030634
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.027835
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.058388
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.057199
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.151349
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.052396
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.053324
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.216448
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.082292
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.070924
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.026157
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.022072
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.031574
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.085759
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.115305
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.029185
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.085520
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.041651
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.013067
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.047131
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.082627
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.020820
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.014436
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.042161
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.077757
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.142759
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.074323
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.022038
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.039424
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.062482
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.160461
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.030882
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.064951
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.104569
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.168543
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.009774
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.022183
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.014887
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.017433
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.030222
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.150944
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0