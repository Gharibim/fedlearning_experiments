# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs
from utils import averageModels, normalModels

# %%
class Arguments():
    def __init__(self):
        self.images = 60000
        self.clients = 5
        self.rounds = 10
        self.epochs = 5
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1.0
        self.drop_rate = 0.0
        self.torch_seed = 0
        self.log_interval = 100
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = False

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
writer = open('5_experiments_mnist.csv', 'a')
writer.write('\n\n\n')
writer.write('Clients {}, Rounds {}, Epochs {}, IID {}'.format(args.clients, args.rounds, args.epochs, args.iid))
writer.write('\n')
# Out:
# 1

# %%
hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process

# %%
# # Download MNIST manually using 'wget' then uncompress the file
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid)

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
#     client['samples'] = len(trainset_ind_list) / args.images
    client['samples'] = len(trainset_ind_list) / (len(trainset_ind_list) * args.clients)

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def ClientUpdate(args, device, client):
    client['model'].train()
#     client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
#             data = data.send(client['hook'])
#             target = target.send(client['hook'])
            
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
            output = client['model'](data)
            loss = F.nll_loss(output, target)
            loss.backward()
            client['optim'].step()
            
            if batch_idx % args.log_interval == 0:
#                 loss = loss.get() 
                print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * batch_idx / len(client['trainset']), loss))
                
#     client['model'].get()

# %%
def test(args, model, device, test_loader, name):
    model.eval()   
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    writer.write('{},'.format(100. * correct / len(test_loader.dataset)))

# %%
def Aggregate(all_models, sample_client):
    all_dicts = {}
    for inds, client in enumerate(all_models):
        all_dicts[client['hook'].id] = all_models[inds]['model'].state_dict()
    output_dict = copy.deepcopy(all_dicts[sample_client])
    for key in all_dicts[sample_client]:
        for val in all_dicts:
            if val == sample_client:
                continue
            output_dict[key] += all_dicts[val][key]
#         output_dict[key] /= float(len(all_dicts))
        output_dict[key] /= float(len(all_models))
    output_model = Net().to(device)
    output_model.load_state_dict(output_dict)
    return output_model

# %%
torch.manual_seed(args.torch_seed)
global_model = Net()
# torch.manual_seed(args.torch_seed)
# normal_avg = Net()
# torch.manual_seed(args.torch_seed)
# fake_model = Net()

for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

start_time = time.time()

for fed_round in range(args.rounds):
    
#     uncomment if you want a randome fraction for C every round
#     args.C = float(format(np.random.random(), '.1f'))
    
    # number of selected clients
    m = int(max(args.C * args.clients, 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
    np.random.seed(fed_round)
    active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
    active_clients = [clients[i] for i in active_clients_inds]
    
    # Training 
    for client in active_clients:
        ClientUpdate(args, device, client)
    
#     # Testing 
#     for client in active_clients:
#         test(args, client['model'], device, client['testset'], client['hook'].id)
    
    # Averaging 
    global_model = averageModels(global_model, active_clients)
#     normal_avg = normalModels(normal_avg, active_clients)
#     fake_model = Aggregate(active_clients, 'client1')
    
    # Testing the average model
    test(args, global_model, device, global_test_loader, 'Global')
#     test(args, normal_avg, device, global_test_loader, 'Global')
#     test(args, fake_model, device, global_test_loader, 'Global')
    
#     break
            
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())

writer.write('\n')
end_time = time.time() 
hours, rem = divmod(end_time-start_time, 3600)
minutes, seconds = divmod(rem, 60)
writer.write('{:0>2}:{:0>2}:{:05.2f}'.format(int(hours),int(minutes),seconds))
writer.write('\n')
writer.close()

if (args.save_model):
    torch.save(global_model.state_dict(), "FedAvg.pt")
# Out:
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.312409
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.210200
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.695333
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.484380
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.326328
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.160283
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.254630
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.280988
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.297055
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.127146
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.319904
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.307307
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.568714
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.344530
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.397112
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.396674
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.196200
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.186076
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.175233
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.153745
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.320340
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.198466
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.535064
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.437902
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.442365
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.267823
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.324219
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.305271
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.281176
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.119724
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.324182
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.090364
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.398441
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.374103
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.206763
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.383896
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.340043
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.162760
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.154247
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.150936
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.310031
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.256259
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.652084
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.343384
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.430592
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.164233
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.314569
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.359523
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.315863
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.215174
#
# Test set: Average loss for Global model: 0.1472, Accuracy: 9546/10000 (95%)
#
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.087818
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.170446
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.174819
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.151752
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.222406
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.138239
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.184964
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.124322
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.050942
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.048663
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.112762
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.149376
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.169581
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.147672
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.175607
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.179525
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.126646
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.136299
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.036171
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.066503
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.208001
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.082386
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.126962
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.190777
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.098462
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.062731
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.062553
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.057591
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.179416
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.076940
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.140155
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.223260
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.136985
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.176908
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.142604
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.052647
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.132469
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.188470
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.142302
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.046455
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.106765
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.171431
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.120557
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.152014
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.080824
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.084101
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.071001
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.146560
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.188478
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.069346
#
# Test set: Average loss for Global model: 0.0815, Accuracy: 9754/10000 (98%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.054524
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.076927
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.121396
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.013647
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.030565
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.106144
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.020289
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.089277
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.047284
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.076714
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.037167
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.123037
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.046604
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.139252
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.103874
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.108606
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.102096
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.064615
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.011581
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.067585
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.040961
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.183099
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.104510
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.060240
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.085559
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.054733
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.018068
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.068630
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.082447
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.035671
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.128834
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.062282
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.026526
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.075009
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.060070
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.133974
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.071577
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.096117
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.123391
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.089511
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.069800
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.158578
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.088661
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.042945
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.062812
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.071984
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.030664
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.072686
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.048024
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.024997
#
# Test set: Average loss for Global model: 0.0603, Accuracy: 9815/10000 (98%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.047630
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.052686
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.008421
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.036214
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.087600
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.064702
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.054997
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.030253
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.017135
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.038575
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.082073
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.131319
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.187082
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.084722
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.028801
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.087342
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.063978
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.034938
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.018343
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.120939
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.032275
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.035940
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.107542
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.043454
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.040055
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.032191
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.182571
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.041458
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.018739
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.047578
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.051126
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.105102
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.138441
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.076606
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.044747
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.110554
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.043239
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.028124
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.020495
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.019587
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.080600
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.015864
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.024940
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.116870
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.055891
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.163986
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.109353
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.078678
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.064232
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.022840
#
# Test set: Average loss for Global model: 0.0515, Accuracy: 9843/10000 (98%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.016679
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.076762
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.039658
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.034155
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.018239
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.021916
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.023910
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.021631
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.040316
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.015690
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.186664
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.026577
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.066820
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.021827
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.035720
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.010881
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.039312
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.132113
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.011509
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.030352
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.063799
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.173482
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.093957
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.037618
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.251596
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.012341
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.030031
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.054825
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.152018
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.028940
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.046825
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.056144
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.044532
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.077846
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.063737
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.100268
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.069818
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.034998
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.030678
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.017389
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.037425
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.014271
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.080191
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.013103
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.043759
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.020783
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.034936
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.102136
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.046005
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.042245
#
# Test set: Average loss for Global model: 0.0461, Accuracy: 9851/10000 (99%)
#
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.008550
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.020604
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.001441
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.006126
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.026279
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.048792
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.011927
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.027004
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.031084
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.039755
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.022336
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.018224
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.066911
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.008307
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.018713
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.005393
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.031396
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.038337
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.022667
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.009807
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.012426
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.021908
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.111909
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.128360
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.011960
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.078482
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.015200
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.029465
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.077319
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.037849
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.013812
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.100860
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.012250
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.120605
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.048864
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.166189
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.114638
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.054325
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.073553
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.009458
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.125107
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.014679
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.009848
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.023152
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.013538
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.011112
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.018487
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.024860
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.064188
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.004736
#
# Test set: Average loss for Global model: 0.0409, Accuracy: 9867/10000 (99%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.006539
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.167742
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.005035
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.017938
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.020307
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.046123
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.083800
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.018528
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.029148
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.041615
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.244291
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.084315
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.008988
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.034948
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.010188
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.004786
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.017283
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.038622
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.011640
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.066534
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.004759
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.026922
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.020547
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.012227
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.027230
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.006664
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.023269
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.013477
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.045790
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.068106
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.003703
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.037340
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.133329
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.006554
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.011043
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.023785
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.008282
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.013288
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.021090
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.118957
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.033876
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.118170
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.010974
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.112863
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.032003
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.027437
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.018448
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.028577
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.087503
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.034113
#
# Test set: Average loss for Global model: 0.0366, Accuracy: 9875/10000 (99%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.041691
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.076486
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.013908
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.016565
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.072706
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.032679
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.003512
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.023734
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.007770
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.028642
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.014170
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.040630
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.055269
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.042387
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.030317
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.033517
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.027716
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.008789
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.045463
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.006854
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.069358
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.070451
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.024804
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.113734
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.010329
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.026199
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.005003
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.011067
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.015279
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.008363
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.036705
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.141002
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.072727
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.031982
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.085141
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.025222
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.031866
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.013056
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.041506
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.006132
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.021726
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.017087
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.065501
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.013014
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.018889
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.007211
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.007926
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.012693
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.074866
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.011641
#
# Test set: Average loss for Global model: 0.0353, Accuracy: 9875/10000 (99%)
#
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.016361
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.059095
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.009455
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.060511
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.039047
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.020095
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.019918
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.013703
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.004806
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.047805
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.008021
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.082175
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.151056
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.042419
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.059032
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.002544
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.084362
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.022666
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.031014
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.020551
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.017921
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.073987
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.007726
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.109323
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.013433
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.064383
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.132075
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.004988
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.021165
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.008382
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.006418
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.073947
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.016261
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.012818
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.019314
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.006685
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.005923
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.025015
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.021015
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.013628
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.006107
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.034458
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.008780
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.021741
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.012548
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.025962
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.032156
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.051259
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.003448
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.010237
#
# Test set: Average loss for Global model: 0.0334, Accuracy: 9882/10000 (99%)
#
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.021795
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.044156
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.012193
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.017355
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.027513
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.011647
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.019854
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.003468
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.056625
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.007569
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.010233
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.034719
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.066900
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.039825
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.010073
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.001671
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.026158
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.034835
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.004259
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.020498
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.036918
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.135147
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.022786
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.040831
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.012355
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.019745
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.050711
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.052709
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.003176
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.002542
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.012405
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.029544
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.010627
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.023651
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.013854
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.046397
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.026832
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.028604
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.006183
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.009104
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.068165
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.021205
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.004599
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.011773
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.029345
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.164559
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.005626
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.041839
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.015306
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.005890
#
# Test set: Average loss for Global model: 0.0329, Accuracy: 9883/10000 (99%)

# %%
clients[9]['trainset']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-e4e6e1f287ac> in <module>
# ----> 1 clients[9]['trainset']
#
# IndexError: list index out of range
