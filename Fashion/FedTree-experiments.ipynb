# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time
import binarytree

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs
from utils import averageModels, normalModels

# %%
class Arguments():
    def __init__(self):
        self.images = 60000
        self.clients = 5
        self.rounds = 10
        self.epochs = 5
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1.0
        self.drop_rate = 0.0
        self.torch_seed = 0
        self.log_interval = 100
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = False

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
writer = open('5_experiments_fashio.csv', 'a')

# %%
hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})

# %%
# # Download MNIST manually using 'wget' then uncompress the file
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid)

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
#     client['samples'] = len(trainset_ind_list) / args.images
    client['samples'] = len(trainset_ind_list) / (len(trainset_ind_list) * args.clients)

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.FashionMNIST('./', train=False, download=True, transform=transform)
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def ClientUpdate(args, device, client):
    client['model'].train()
#     client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
#             data = data.send(client['hook'])
#             target = target.send(client['hook'])
            
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
            output = client['model'](data)
            loss = F.nll_loss(output, target)
            loss.backward()
            client['optim'].step()
            
            if batch_idx % args.log_interval == 0:
#                 loss = loss.get() 
                print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * batch_idx / len(client['trainset']), loss))
                
#     client['model'].get()

# %%
def test(args, model, device, test_loader, name):
    model.eval()   
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    writer.write('{},'.format(100. * correct / len(test_loader.dataset)))

# %%
def Aggregate(all_models, sample_client):
    all_dicts = {}
    for client in all_models:
        all_dicts[client] = all_models[client].state_dict()
    output_dict = copy.deepcopy(all_dicts[sample_client])
    for key in all_dicts[sample_client]:
        for val in all_dicts:
            if val == sample_client:
                continue
            output_dict[key] += all_dicts[val][key]
#         output_dict[key] /= float(len(all_dicts))
        output_dict[key] /= float(len(all_models))
    output_model = Net().to(device)
    output_model.load_state_dict(output_dict)
    return output_model

# %%
def BtreeAvg(root):
    global global_model
    temp_model = Aggregate({'root':root.value[1], 'global':global_model}, 'global')
    
    if (root.left == None and root.right == None): 
        return temp_model
    left = None
    right = None
    if root.left:
        left = BtreeAvg(root.left)
    if root.right:
        right = BtreeAvg(root.right)

    if left and right:
        return Aggregate({'root':root.value[1], 'left':left, 'right':right}, 'left')
    if left:
        return Aggregate({'root':root.value[1], 'left':left}, 'left')
    if right:
        return Aggregate({'root':root.value[1],'right':right}, 'right')

# %%
def BtreeAvgSecond(root, final):
    temp_model = Aggregate({'root':root.value[1], 'global':final}, 'global')
    
    if (root.left == None and root.right == None): 
        return temp_model
    left = None
    right = None
    if root.left:
        left = BtreeAvgSecond(root.left, temp_model)
    if root.right:
        right = BtreeAvgSecond(root.right, temp_model)

    if left and right:
        return Aggregate({'root':root.value[1], 'left':left, 'right':right}, 'left')
    if left:
        return Aggregate({'root':root.value[1], 'left':left}, 'left')
    if right:
        return Aggregate({'root':root.value[1],'right':right}, 'right')

# %%
torch.manual_seed(args.torch_seed)
global_model = Net()
# torch.manual_seed(args.torch_seed)
# normal_avg = Net()

for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

tree_List = []
for inds, i in enumerate(clients):
    temp = [None] * 3
    temp[0] = i
    temp[1] = clients[inds]['model']
    temp[2] = clients[inds]['hook'].id
    tree_List.append(temp)

root = None
root = binarytree.insertLevelOrder(tree_List, root, 0, len(tree_List))
# root.printTree()

start_time = time.time()

for fed_round in range(args.rounds):
    
#     uncomment if you want a randome fraction for C every round
#     args.C = float(format(np.random.random(), '.1f'))
    
    # number of selected clients
    m = int(max(args.C * args.clients, 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
    np.random.seed(fed_round)
    active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
    active_clients = [clients[i] for i in active_clients_inds]
    
    # Training 
    for client in active_clients:
        ClientUpdate(args, device, client)
        
#     global_model = averageModels(global_model, active_clients)
#     test(args, global_model, device, global_test_loader, 'Global')
#     normal_avg = normalModels(normal_avg, active_clients)
#     test(args, normal_avg, device, global_test_loader, 'Global')
    
    
    # Begin the Btree
#     final_model = BtreeAvg(root)
    final_model = BtreeAvgSecond(root, global_model)
#     glo_model = copy.deepcopy(final_model)
    global_model.load_state_dict(final_model.state_dict())
#     test(args, global_model, device, global_test_loader, 'Global')
#     break
    
#     # Testing 
#     for client in active_clients:
#         test(args, client['model'], device, client['testset'], client['hook'].id)
    
#     # Averaging 
#     global_model = averageModels(global_model, active_clients)
    
    # Testing the average model
    test(args, global_model, device, global_test_loader, 'Global')
            
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())

writer.write('\n')
end_time = time.time() 
hours, rem = divmod(end_time-start_time, 3600)
minutes, seconds = divmod(rem, 60)
writer.write('{:0>2}:{:0>2}:{:05.2f}'.format(int(hours),int(minutes),seconds))
writer.write('\n')
writer.close()

if (args.save_model):
    torch.save(global_model.state_dict(), "FedAvg.pt")
# Out:
# /Users/mohamedghribi/anaconda3/envs/iswc/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.297563
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.262483
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.865362
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.815645
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 1.036151
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.719775
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.503071
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.884989
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.909817
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.578527
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.334222
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.223064
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 1.052147
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 1.064292
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.733021
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.655474
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.755719
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.667276
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.660451
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.597529
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.324395
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.334797
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.874199
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.914214
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 1.006341
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.717270
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.823319
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.623130
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.459314
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.625033
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.324375
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.216504
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 1.119431
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.771234
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.829991
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.625929
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.682420
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.727061
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.677624
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.578572
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.319403
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 1.326059
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.972039
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.899540
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.918754
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.652026
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.930004
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.741422
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.767542
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.522335
#
# Test set: Average loss for Global model: 0.6489, Accuracy: 7750/10000 (78%)
#
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.641915
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.637304
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.896034
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.690693
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.539928
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.424830
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.579874
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.617476
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.497007
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.515517
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.630199
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.634372
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.775934
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.577423
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.609468
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.613264
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.391557
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.411002
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.648513
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.647048
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.666510
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.473039
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.517892
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.496882
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.541975
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.539003
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.439054
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.614458
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.476661
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.375180
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.605685
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.604710
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.551043
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.536338
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.464269
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.580556
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.664132
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.546639
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.455943
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.442664
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.640748
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.550925
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.651335
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.529454
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.727287
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.504640
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.481459
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.357077
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.497527
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.395123
#
# Test set: Average loss for Global model: 0.5185, Accuracy: 8116/10000 (81%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.545990
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.431381
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.519965
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.495017
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.508973
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.533075
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.222237
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.440206
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.589320
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.441477
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.685409
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.520798
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.452391
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.381706
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.602688
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.467125
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.454147
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.319053
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.460549
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.629739
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.625609
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.557082
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.554516
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.538858
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.519138
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.360718
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.633859
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.425058
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.351118
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.667738
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.606630
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.495785
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.702117
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.517241
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.437816
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.727220
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.483760
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.324481
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.308666
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.393411
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.367184
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.552888
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.233937
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.588542
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.575486
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.452795
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.449295
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.583561
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.365721
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.460571
#
# Test set: Average loss for Global model: 0.4584, Accuracy: 8364/10000 (84%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.268458
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.453453
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.222760
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.320229
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.665344
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.391153
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.480577
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.349025
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.355386
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.589551
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.631118
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.456775
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.373198
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.540042
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.360799
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.682998
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.415145
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.371361
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.416544
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.369119
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.291013
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.422429
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.411513
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.304799
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.322392
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.377336
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.440917
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.717125
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.461205
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.353480
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.369494
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.423113
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.635675
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.389646
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.277444
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.466302
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.522863
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.397636
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.468729
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.425496
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.499469
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.767030
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.382684
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.294276
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.627613
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.528098
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.376073
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.421166
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.517808
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.394962
#
# Test set: Average loss for Global model: 0.4158, Accuracy: 8521/10000 (85%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.303976
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.407980
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.595186
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.300318
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.596669
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.466557
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.331693
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.309518
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.459713
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.488988
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.402946
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.423744
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.423761
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.461539
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.493521
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.556369
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.346991
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.323595
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.356916
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.345749
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.298785
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.462709
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.283545
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.354544
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.277369
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.376517
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.323736
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.447536
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.475990
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.564778
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.454226
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.408857
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.493756
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.424559
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.397988
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.277521
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.401923
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.435900
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.236801
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.340482
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.390011
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.392016
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.414656
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.432376
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.543244
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.542656
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.407170
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.267370
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.361158
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.247503
#
# Test set: Average loss for Global model: 0.3929, Accuracy: 8596/10000 (86%)
#
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.223380
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.407264
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.305955
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.277455
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.332614
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.372010
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.364948
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.282550
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.240707
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.267179
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.219808
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.538641
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.304647
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.374946
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.531308
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.417285
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.318668
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.349306
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.454932
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.472983
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.446432
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.278084
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.452658
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.215671
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.337668
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.541511
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.366887
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.333181
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.336103
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.358804
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.262071
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.189136
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.295679
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.458105
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.306719
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.336258
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.425030
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.393084
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.455184
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.231459
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.276932
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.430001
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.362723
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.313864
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.451761
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.414307
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.359950
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.307282
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.381557
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.317784
#
# Test set: Average loss for Global model: 0.3828, Accuracy: 8649/10000 (86%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.286460
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.219504
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.406431
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.357952
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.550155
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.516369
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.323008
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.481439
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.479316
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.316207
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.371688
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.320455
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.378016
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.290573
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.298409
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.227228
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.356971
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.287021
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.274279
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.274591
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.397554
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.271947
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.557576
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.409023
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.279946
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.372417
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.395828
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.247992
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.443373
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.282534
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.356084
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.489024
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.564229
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.192938
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.288536
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.280585
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.374943
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.445076
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.337574
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.407122
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.508703
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.306844
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.138069
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.393709
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.386470
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.495695
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.323209
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.308417
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.309631
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.506141
#
# Test set: Average loss for Global model: 0.3608, Accuracy: 8711/10000 (87%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.491626
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.243779
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.254562
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.312690
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.275797
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.234363
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.330532
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.243573
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.321933
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.173666
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.303887
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.564660
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.370957
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.443268
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.251996
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.322008
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.283325
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.311659
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.289615
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.345294
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.443650
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.449775
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.372939
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.301814
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.282266
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.231617
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.269587
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.293319
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.451996
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.384861
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.347976
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.307224
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.203476
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.372398
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.375768
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.250237
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.392824
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.615991
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.237782
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.299303
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.278972
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.392001
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.335538
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.301805
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.545732
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.438882
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.222521
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.518396
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.239216
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.263867
#
# Test set: Average loss for Global model: 0.3533, Accuracy: 8731/10000 (87%)
#
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.365706
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.391885
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.126394
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.382781
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.402079
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.255765
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.353731
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.322197
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.505537
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.143964
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.326531
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.331640
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.337654
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.372503
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.299233
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.196937
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.326491
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.229944
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.177979
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.192986
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.249014
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.368129
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.199532
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.250639
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.227842
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.229613
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.298026
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.361003
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.306708
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.224568
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.209415
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.276656
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.403548
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.235614
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.381613
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.374657
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.477331
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.271859
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.306423
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.512200
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.197979
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.289674
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.211719
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.181576
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.349437
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.309934
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.270545
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.263900
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.266902
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.276715
#
# Test set: Average loss for Global model: 0.3416, Accuracy: 8770/10000 (88%)
#
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.243386
# Model client3 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.301794
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.201750
# Model client3 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.246682
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.125020
# Model client3 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.463545
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.183031
# Model client3 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.266316
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.496149
# Model client3 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.218055
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.338973
# Model client4 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.327552
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.454160
# Model client4 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.275142
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.469508
# Model client4 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.266411
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.282899
# Model client4 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.210029
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.400707
# Model client4 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.326205
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.326553
# Model client1 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.329852
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.282436
# Model client1 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.359813
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.196591
# Model client1 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.156064
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.437156
# Model client1 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.244290
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.334077
# Model client1 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.206938
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.160548
# Model client2 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.272750
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.246148
# Model client2 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.390895
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.326512
# Model client2 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.276141
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.488125
# Model client2 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.254632
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.195973
# Model client2 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.378257
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.351621
# Model client5 Train Epoch: 1 [6400/12032 (53%)]	Loss: 0.279482
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.392346
# Model client5 Train Epoch: 2 [6400/12032 (53%)]	Loss: 0.254301
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.324734
# Model client5 Train Epoch: 3 [6400/12032 (53%)]	Loss: 0.300307
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.275477
# Model client5 Train Epoch: 4 [6400/12032 (53%)]	Loss: 0.272794
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.292326
# Model client5 Train Epoch: 5 [6400/12032 (53%)]	Loss: 0.355618
#
# Test set: Average loss for Global model: 0.3433, Accuracy: 8745/10000 (87%)
