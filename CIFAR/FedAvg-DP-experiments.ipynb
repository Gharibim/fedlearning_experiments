# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time
from opacus import PrivacyEngine

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs
from utils import averageModels, normalModels

# %%
class Arguments():
    def __init__(self):
        self.images = 50000
        self.clients = 5
        self.rounds = 10
        self.epochs = 5
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1.0
        self.drop_rate = 0.0
        self.torch_seed = 0
        self.log_interval = 100
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = False

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
writer = open('5_experiments_cifar.csv', 'a')

# %%
hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process

# %%
# # Download MNIST manually using 'wget' then uncompress the file
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
#     client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
#     client['samples'] = len(trainset_ind_list) / args.images
    client['samples'] = len(trainset_ind_list) / (len(trainset_ind_list) * args.clients)

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
global_test_dataset = datasets.CIFAR10('./', train=False, download=True, transform=transform)
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)
# Out:
# Files already downloaded and verified

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

# %%
def ClientUpdate(args, device, client):
    client['model'].train()
#     client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
#             data = data.send(client['hook'])
#             target = target.send(client['hook'])
            
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
            output = client['model'](data)
            loss = F.nll_loss(output, target)
            loss.backward()
            client['optim'].step()
            
            if batch_idx % args.log_interval == 0:
#                 loss = loss.get() 
                print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * batch_idx / len(client['trainset']), loss))
                
#     client['model'].get()

# %%
def test(args, model, device, test_loader, name):
    model.eval()   
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    writer.write('{},'.format(100. * correct / len(test_loader.dataset)))

# %%
def Aggregate(all_models, sample_client):
    all_dicts = {}
    for inds, client in enumerate(all_models):
        all_dicts[client['hook'].id] = all_models[inds]['model'].state_dict()
    output_dict = copy.deepcopy(all_dicts[sample_client])
    for key in all_dicts[sample_client]:
        for val in all_dicts:
            if val == sample_client:
                continue
            output_dict[key] += all_dicts[val][key]
#         output_dict[key] /= float(len(all_dicts))
        output_dict[key] /= float(len(all_models))
    output_model = Net().to(device)
    output_model.load_state_dict(output_dict)
    return output_model

# %%
torch.manual_seed(args.torch_seed)
global_model = Net()
# torch.manual_seed(args.torch_seed)
# normal_avg = Net()
# torch.manual_seed(args.torch_seed)
# fake_model = Net()

for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)
#     print('images {} batches {} sample size {}'.format(args.images, args.local_batches, len(client['trainset'])))
#     print(args.local_batches/len(client['trainset']))
    client['pengine'] = PrivacyEngine(
                                       client['model'],
                                       batch_size=args.local_batches,
                                       sample_size=len(client['trainset']),
                                       sample_rate=0.01,
                                       alphas=range(2,32),
                                       noise_multiplier=1.3,
                                       max_grad_norm=1.0,
                                    )
    client['pengine'].attach(client['optim'])

start_time = time.time()

for fed_round in range(args.rounds):
    
#     uncomment if you want a randome fraction for C every round
#     args.C = float(format(np.random.random(), '.1f'))
    
    # number of selected clients
    m = int(max(args.C * args.clients, 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
    np.random.seed(fed_round)
    active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
    active_clients = [clients[i] for i in active_clients_inds]
    
    # Training 
    for client in active_clients:
        ClientUpdate(args, device, client)
    
#     # Testing 
#     for client in active_clients:
#         test(args, client['model'], device, client['testset'], client['hook'].id)
    
    # Averaging 
    global_model = averageModels(global_model, active_clients)
#     normal_avg = normalModels(normal_avg, active_clients)
#     fake_model = Aggregate(active_clients, 'client1')
    
    # Testing the average model
    test(args, global_model, device, global_test_loader, 'Global')
#     test(args, normal_avg, device, global_test_loader, 'Global')
#     test(args, fake_model, device, global_test_loader, 'Global')
    
#     break
            
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())

writer.write('\n')
end_time = time.time() 
hours, rem = divmod(end_time-start_time, 3600)
minutes, seconds = divmod(rem, 60)
writer.write('{:0>2}:{:0>2}:{:05.2f}'.format(int(hours),int(minutes),seconds))
writer.write('\n')
writer.close()

if (args.save_model):
    torch.save(global_model.state_dict(), "FedAvg.pt")
# Out:
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:646: UserWarning: A ``sample_rate`` has been provided.Thus, the provided ``batch_size``and ``sample_size`` will be ignored.
#   "A ``sample_rate`` has been provided."
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:230: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:646: UserWarning: A ``sample_rate`` has been provided.Thus, the provided ``batch_size``and ``sample_size`` will be ignored.
#   "A ``sample_rate`` has been provided."
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:230: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:646: UserWarning: A ``sample_rate`` has been provided.Thus, the provided ``batch_size``and ``sample_size`` will be ignored.
#   "A ``sample_rate`` has been provided."
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:230: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:646: UserWarning: A ``sample_rate`` has been provided.Thus, the provided ``batch_size``and ``sample_size`` will be ignored.
#   "A ``sample_rate`` has been provided."
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:230: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:646: UserWarning: A ``sample_rate`` has been provided.Thus, the provided ``batch_size``and ``sample_size`` will be ignored.
#   "A ``sample_rate`` has been provided."
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/opacus/privacy_engine.py:230: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /Users/gharibi/opt/anaconda3/envs/iswc/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# Model client2 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.295015
# Model client2 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.291405
# Model client2 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.290272
# Model client2 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.306907
# Model client2 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.308695
# Model client2 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.294508
# Model client2 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.305912
# Model client2 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.302574
# Model client2 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.306912
# Model client2 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.310273
# Model client3 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.307770
# Model client3 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.304159
# Model client3 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.294698
# Model client3 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.298735
# Model client3 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.306877
# Model client3 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.292866
# Model client3 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.306752
# Model client3 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.307202
# Model client3 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.306562
# Model client3 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.305229
# Model client1 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.297213
# Model client1 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.303607
# Model client1 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.305445
# Model client1 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.290781
# Model client1 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.301790
# Model client1 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.308760
# Model client1 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.299408
# Model client1 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.302554
# Model client1 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.289330
# Model client1 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.297546
# Model client4 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.310629
# Model client4 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.327416
# Model client4 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.306572
# Model client4 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.295108
# Model client4 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.310536
# Model client4 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.303373
# Model client4 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.291324
# Model client4 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.295707
# Model client4 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.296422
# Model client4 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.303872
# Model client5 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.313994
# Model client5 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.303875
# Model client5 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.310357
# Model client5 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.289574
# Model client5 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.310874
# Model client5 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.293173
# Model client5 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.305619
# Model client5 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.301556
# Model client5 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.291363
# Model client5 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.295699
#
# Test set: Average loss for Global model: 2.2980, Accuracy: 1090/10000 (11%)
#
# Model client5 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.302734
# Model client5 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.299156
# Model client5 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.283547
# Model client5 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.294297
# Model client5 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.287838
# Model client5 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.286422
# Model client5 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.265840
# Model client5 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.281741
# Model client5 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.262067
# Model client5 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.261287
# Model client2 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.299783
# Model client2 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.292261
# Model client2 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.298401
# Model client2 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.289489
# Model client2 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.298457
# Model client2 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.274220
# Model client2 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.293735
# Model client2 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.284372
# Model client2 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.261193
# Model client2 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.262849
# Model client4 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.297498
# Model client4 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.295350
# Model client4 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.291870
# Model client4 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.298523
# Model client4 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.295408
# Model client4 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.265479
# Model client4 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.299515
# Model client4 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.279725
# Model client4 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.265825
# Model client4 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.265006
# Model client3 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.303704
# Model client3 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.286356
# Model client3 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.292880
# Model client3 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.305240
# Model client3 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.284719
# Model client3 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.292219
# Model client3 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.270881
# Model client3 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.295062
# Model client3 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.279308
# Model client3 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.273333
# Model client1 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.300837
# Model client1 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.309159
# Model client1 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.295125
# Model client1 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.303904
# Model client1 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.298067
# Model client1 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.274785
# Model client1 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.275696
# Model client1 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.270965
# Model client1 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.265847
# Model client1 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.269350
#
# Test set: Average loss for Global model: 2.2566, Accuracy: 1635/10000 (16%)
#
# Model client2 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.264991
# Model client2 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.244824
# Model client2 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.220317
# Model client2 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.222923
# Model client2 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.205709
# Model client2 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.200527
# Model client2 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.164994
# Model client2 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.180036
# Model client2 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.203150
# Model client2 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.139368
# Model client1 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.241655
# Model client1 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.222709
# Model client1 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.218177
# Model client1 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.214427
# Model client1 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.198987
# Model client1 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.153337
# Model client1 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.166031
# Model client1 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.161295
# Model client1 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.160739
# Model client1 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.154744
# Model client5 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.279343
# Model client5 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.226334
# Model client5 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.244791
# Model client5 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.221490
# Model client5 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.207937
# Model client5 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.179034
# Model client5 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.184608
# Model client5 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.150762
# Model client5 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.215059
# Model client5 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.101646
# Model client4 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.242085
# Model client4 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.236232
# Model client4 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.234392
# Model client4 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.244416
# Model client4 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.220285
# Model client4 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.243310
# Model client4 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.218243
# Model client4 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.169544
# Model client4 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.102829
# Model client4 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.156304
# Model client3 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.261371
# Model client3 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.253890
# Model client3 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.203058
# Model client3 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.197771
# Model client3 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.221395
# Model client3 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.222664
# Model client3 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.209497
# Model client3 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.141819
# Model client3 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.128686
# Model client3 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.129769
#
# Test set: Average loss for Global model: 2.1231, Accuracy: 2256/10000 (23%)
#
# Model client1 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.171308
# Model client1 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2
# Model client4 Train Epoch: 1 [0/10048 (0%)]	Loss: 1.774371
# Model client4 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.172556
# Model client4 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.011269
# Model client4 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.243753
# Model client4 Train Epoch: 3 [0/10048 (0%)]	Loss: 1.923801
# Model client4 Train Epoch: 3 [6400/10048 (64%)]	Loss: 1.984229
# Model client4 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.189836
# Model client4 Train Epoch: 4 [6400/10048 (64%)]	Loss: 1.916000
# Model client4 Train Epoch: 5 [0/10048 (0%)]	Loss: 1.758300
# Model client4 Train Epoch: 5 [6400/10048 (64%)]	Loss: 1.821051
# Model client2 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.058316
# Model client2 Train Epoch: 1 [6400/10048 (64%)]	Loss: 1.928517
# Model client2 Train Epoch: 2 [0/10048 (0%)]	Loss: 1.879746
# Model client2 Train Epoch: 2 [6400/10048 (64%)]	Loss: 1.907809
# Model client2 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.047356
# Model client2 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.171465
# Model client2 Train Epoch: 4 [0/10048 (0%)]	Loss: 1.914205
# Model client2 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.025413
# Model client2 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.331181
# Model client2 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.158923
# Model client3 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.207515
# Model client3 Train Epoch: 1 [6400/10048 (64%)]	Loss: 1.825309
# Model client3 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.005762
# Model client3 Train Epoch: 2 [6400/10048 (64%)]	Loss: 1.884367
# Model client3 Train Epoch: 3 [0/10048 (0%)]	Loss: 1.859801
# Model client3 Train Epoch: 3 [6400/10048 (64%)]	Loss: 1.977726
# Model client3 Train Epoch: 4 [0/10048 (0%)]	Loss: 1.985549
# Model client3 Train Epoch: 4 [6400/10048 (64%)]	Loss: 1.963723
# Model client3 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.249188
# Model client3 Train Epoch: 5 [6400/10048 (64%)]	Loss: 1.989437
# Model client5 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.049133
# Model client5 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.033939
# Model client5 Train Epoch: 2 [0/10048 (0%)]	Loss: 1.975412
# Model client5 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.116339
# Model client5 Train Epoch: 3 [0/10048 (0%)]	Loss: 1.769539
# Model client5 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.059701
# Model client5 Train Epoch: 4 [0/10048 (0%)]	Loss: 1.958500
# Model client5 Train Epoch: 4 [6400/10048 (64%)]	Loss: 1.790754
# Model client5 Train Epoch: 5 [0/10048 (0%)]	Loss: 1.951155
# Model client5 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.215422
# Model client1 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.002362
# Model client1 Train Epoch: 1 [6400/10048 (64%)]	Loss: 1.969474
# Model client1 Train Epoch: 2 [0/10048 (0%)]	Loss: 1.934954
# Model client1 Train Epoch: 2 [6400/10048 (64%)]	Loss: 1.990479
# Model client1 Train Epoch: 3 [0/10048 (0%)]	Loss: 1.777870
# Model client1 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.033883
# Model client1 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.064607
# Model client1 Train Epoch: 4 [6400/10048 (64%)]	Loss: 1.977312
# Model client1 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.034339
# Model client1 Train Epoch: 5 [6400/10048 (64%)]	Loss: 1.887206
#
# Test set: Average loss for Global model: 1.9893, Accuracy: 2925/10000 (29%)
#
# Model client3 Train Epoch: 1 [0/10048 (0%)]	Loss: 1.916330
# Model client3 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.463908
# Model client3 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.124616
# Model client3 Train Epoch: 2 [6400/10048 (64%)]	Loss: 1.892735
# Model client3 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.032248
# Model client3 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.132576
# Model client3 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.015147
# Model client3 Train Epoch: 4 [6400/10048 (64%)]	Loss: 1.860883
# Model client3 Train Epoch: 5 [0/10048 (0%)]	Loss: 1.853562
# Model client3 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.079832
# Model client4 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.232294
# Model client4 Train Epoch: 1 [6400/10048 (64%)]	Loss: 2.030789
# Model client4 Train Epoch: 2 [0/10048 (0%)]	Loss: 1.927408
# Model client4 Train Epoch: 2 [6400/10048 (64%)]	Loss: 1.814408
# Model client4 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.175616
# Model client4 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.018715
# Model client4 Train Epoch: 4 [0/10048 (0%)]	Loss: 1.968709
# Model client4 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.002985
# Model client4 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.172599
# Model client4 Train Epoch: 5 [6400/10048 (64%)]	Loss: 1.879628
# Model client1 Train Epoch: 1 [0/10048 (0%)]	Loss: 2.063333
# Model client1 Train Epoch: 1 [6400/10048 (64%)]	Loss: 1.953287
# Model client1 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.121983
# Model client1 Train Epoch: 2 [6400/10048 (64%)]	Loss: 1.838751
# Model client1 Train Epoch: 3 [0/10048 (0%)]	Loss: 1.810366
# Model client1 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.156048
# Model client1 Train Epoch: 4 [0/10048 (0%)]	Loss: 1.826876
# Model client1 Train Epoch: 4 [6400/10048 (64%)]	Loss: 1.978744
# Model client1 Train Epoch: 5 [0/10048 (0%)]	Loss: 2.068970
# Model client1 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.054292
# Model client2 Train Epoch: 1 [0/10048 (0%)]	Loss: 1.843825
# Model client2 Train Epoch: 1 [6400/10048 (64%)]	Loss: 1.849481
# Model client2 Train Epoch: 2 [0/10048 (0%)]	Loss: 2.005448
# Model client2 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.199956
# Model client2 Train Epoch: 3 [0/10048 (0%)]	Loss: 1.885103
# Model client2 Train Epoch: 3 [6400/10048 (64%)]	Loss: 2.040135
# Model client2 Train Epoch: 4 [0/10048 (0%)]	Loss: 2.122555
# Model client2 Train Epoch: 4 [6400/10048 (64%)]	Loss: 1.893964
# Model client2 Train Epoch: 5 [0/10048 (0%)]	Loss: 1.877345
# Model client2 Train Epoch: 5 [6400/10048 (64%)]	Loss: 1.819389
# Model client5 Train Epoch: 1 [0/10048 (0%)]	Loss: 1.867522
# Model client5 Train Epoch: 1 [6400/10048 (64%)]	Loss: 1.776826
# Model client5 Train Epoch: 2 [0/10048 (0%)]	Loss: 1.831984
# Model client5 Train Epoch: 2 [6400/10048 (64%)]	Loss: 2.076510
# Model client5 Train Epoch: 3 [0/10048 (0%)]	Loss: 2.037453
# Model client5 Train Epoch: 3 [6400/10048 (64%)]	Loss: 1.985668
# Model client5 Train Epoch: 4 [0/10048 (0%)]	Loss: 1.960058
# Model client5 Train Epoch: 4 [6400/10048 (64%)]	Loss: 2.002301
# Model client5 Train Epoch: 5 [0/10048 (0%)]	Loss: 1.945411
# Model client5 Train Epoch: 5 [6400/10048 (64%)]	Loss: 2.102237
#
# Test set: Average loss for Global model: 1.9831, Accuracy: 2998/10000 (30%)
